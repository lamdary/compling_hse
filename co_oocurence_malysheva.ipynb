# %% [markdown]
# <a href="https://colab.research.google.com/github/lamdary/compling_hse/blob/main/co_oocurence_malysheva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/lamdary/compling_hse/refs/heads/main/harry_potter_data.txt
# Out:
# --2024-11-17 14:15:49--  https://raw.githubusercontent.com/lamdary/compling_hse/refs/heads/main/harry_potter_data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 439742 (429K) [text/plain]
# Saving to: ‘harry_potter_data.txt’
#
# harry_potter_data.t 100%[===================>] 429.44K  --.-KB/s    in 0.05s
#
# 2024-11-17 14:15:49 (9.16 MB/s) - ‘harry_potter_data.txt’ saved [439742/439742]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'harry_potter_data.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[0:1000]
# Out:
# "harry potter and the sorcerer's stone\n\n\nchapter one\n\nthe boy who lived\n\nmr. and mrs. dursley, of number four, privet drive, were proud to say\nthat they were perfectly normal, thank you very much. they were the last\npeople you'd expect to be involved in anything strange or mysterious,\nbecause they just didn't hold with such nonsense.\n\nmr. dursley was the director of a firm called grunnings, which made\ndrills. he was a big, beefy man with hardly any neck, although he did\nhave a very large mustache. mrs. dursley was thin and blonde and had\nnearly twice the usual amount of neck, which came in very useful as she\nspent so much of her time craning over garden fences, spying on the\nneighbors. the dursleys had a small son called dudley and in their\nopinion there was no finer boy anywhere.\n\nthe dursleys had everything they wanted, but they also had a secret, and\ntheir greatest fear was that somebody would discover it. they didn't\nthink they could bear it if anyone found out about the potters. mr"

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[0:1000]
# Out:
# 'harry potter and the sorcerers stone\n\n\nchapter one\n\nthe boy who lived\n\nmr. and mrs. dursley of number four privet drive were proud to say\nthat they were perfectly normal thank you very much. they were the last\npeople youd expect to be involved in anything strange or mysterious\nbecause they just didnt hold with such nonsense.\n\nmr. dursley was the director of a firm called grunnings which made\ndrills. he was a big beefy man with hardly any neck although he did\nhave a very large mustache. mrs. dursley was thin and blonde and had\nnearly twice the usual amount of neck which came in very useful as she\nspent so much of her time craning over garden fences spying on the\nneighbors. the dursleys had a small son called dudley and in their\nopinion there was no finer boy anywhere.\n\nthe dursleys had everything they wanted but they also had a secret and\ntheir greatest fear was that somebody would discover it. they didnt\nthink they could bear it if anyone found out about the potters. mrs.\npotter was mr'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# [' and mrs',
#  ' dursley of number four privet drive were proud to say\nthat they were perfectly normal thank you very much']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['they',
#  'were',
#  'the',
#  'last',
#  'people',
#  'youd',
#  'expect',
#  'to',
#  'be',
#  'involved',
#  'in',
#  'anything',
#  'strange',
#  'or',
#  'mysterious',
#  'because',
#  'they',
#  'just',
#  'didnt',
#  'hold',
#  'with',
#  'such',
#  'nonsense']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = [""] + sentence + [""]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['mysterious']
# Out:
# defaultdict(int,
#             {'or': 2,
#              'because': 2,
#              'and': 2,
#              'things': 2,
#              'most': 2,
#              '': 4,
#              'people': 2,
#              'the': 2,
#              'object': 2,
#              'nothing': 2,
#              'to': 2})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['',
#  'harry',
#  'potter',
#  'and',
#  'the',
#  'sorcerers',
#  'stone',
#  'chapter',
#  'one',
#  'boy']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#                    harry  potter  and  the  sorcerers  stone  chapter  one  \
#                24   1202     124  234  566          0     38       32   94
# harry        1202      4      56  242   14          0      2        0    4
# potter        124     56       0    2   14          0      0        0    0
# and           234    242       2    0  166          0      6        0   14
# the           566     14      14  166    0         24     96        0   26
# ...           ...    ...     ...  ...  ...        ...    ...      ...  ...
# purplefaced     0      0       0    0    0          0      0        0    0
# mustached       0      0       0    0    0          0      0        0    0
# manner          0      0       0    0    0          0      0        0    0
# holiday         0      0       0    0    0          0      0        0    0
# spreading       0      0       0    0    0          0      0        0    0
#
#              boy  ...  twos  threes  alarming  gateway  squealed  purplefaced  \
#               40  ...     0       0         0        0         2            0
# harry          2  ...     0       0         0        0         0            0
# potter         4  ...     0       0         0        0         0            0
# and            4  ...     2       2         2        0         0            0
# the           52  ...     0       0         2        4         0            0
# ...          ...  ...   ...     ...       ...      ...       ...          ...
# purplefaced    0  ...     0       0         0        0         0            0
# mustached      0  ...     0       0         0        0         0            0
# manner         0  ...     0       0         0        0         0            0
# holiday        0  ...     0       0         0        0         0            0
# spreading      0  ...     0       0         0        0         0            0
#
#              mustached  manner  holiday  spreading
#                      0       0        0          0
# harry                0       0        0          0
# potter               0       0        0          0
# and                  0       0        0          0
# the                  0       0        0          0
# ...                ...     ...      ...        ...
# purplefaced          0       0        0          0
# mustached            0       0        0          0
# manner               0       0        0          0
# holiday              0       0        0          0
# spreading            0       0        0          0
#
# [6023 rows x 6023 columns]
